# %%
import pandas as pd
import numpy as np
import os
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import geopandas
import folium
from folium import plugins
import requests
from shapely.geometry import Polygon
import time

# %%
import pandas as pd
import numpy as np
import geopandas
import folium
import matplotlib.pyplot as plt
from folium import plugins


# finalplis=pd.read_stata("finalplis.dta")
a=geopandas.read_file('distritos-peru/distritos-peru.shp',encoding="utf-8")
finalplis0=pd.read_stata("final.dta")

# %%
finalplis1=finalplis0[["distrito","mbuffer"]].groupby(["distrito"]).mean().reset_index()
finalplis1.loc[(finalplis1["distrito"].apply(lambda x: x in list(a["nombdist"]))==False)&(finalplis1["distrito"].apply(lambda x: "BRE" in str(x))),"distrito"]="BREÑA"
finalplis1.loc[(finalplis1["distrito"].apply(lambda x: x in list(a["nombdist"]))==False)&(finalplis1["distrito"].apply(lambda x: "MAG" in str(x))),"distrito"]="MAGDALENA DEL MAR"

finalplis=finalplis1.rename(columns={"distrito":"nombdist","mbuffer":"total"})

a1=a.loc[(a["nombprov"]=="LIMA")|(a["nombdep"].apply(lambda x: "CALLAO" in x))]

a1_0=a1.merge(finalplis, how="left", on="nombdist")

a3=a1_0.loc[a1_0["total"].isna()==False].copy()

colores=list(reversed([
'#1c2475','#18297a','#122e7f','#083385','#00388a','#003d8f',
'#004293','#004798','#004b9d','#0050a1','#0055a6','#005aaa',
'#005fae','#0063b2','#0068b6','#006dba','#0072bd','#0077c1',
'#007cc4','#0080c8','#0085cb','#008ace','#008fd1','#0094d4',
'#0099d7','#009dda','#00a2dc','#00a7df','#00ace1','#00b1e4',
'#00b6e6','#00bae8','#00bfeb','#00c4ed','#00c9ef','#00cef1',
'#00d3f3','#00d7f4','#00dcf6','#1ae1f8']))

bins=np.linspace(min(a3["total"].apply(lambda x: float(x))),max(a3['total'].apply(lambda x: float(x))),len(colores)+1)
a3['color']=pd.cut(a3["total"],bins,labels=colores,include_lowest=True)


a4=a1_0.loc[a1_0["total"].isna()==True].copy()
a4["color"]="#DADADA"


mapa0 = folium.Map(location=[-12.05, -76.9], zoom_start=10, tiles="Cartodb Positron")
folium.LatLngPopup().add_to(mapa0)

def heatmap(x):
    for _, ñ in a3.iloc[x:x+1,:].iterrows():
        sim_geo = geopandas.GeoSeries(ñ['geometry']).simplify(tolerance=0.001)
        geo_j = sim_geo.to_json()
        geo_j = folium.GeoJson(data=geo_j,
                               style_function=lambda x: {'fillColor': ñ["color"],"color":"black","weight": 1.3,"fillOpacity":1})
        folium.Popup(str(ñ["nombdist"])+": "+str(ñ["total"])).add_to(geo_j)
        geo_j.add_to(mapa0)
        
def heatmap2(x):
    for _, ñ in a4.iloc[x:x+1,:].iterrows():
        sim_geo = geopandas.GeoSeries(ñ['geometry']).simplify(tolerance=0.001)
        geo_j = sim_geo.to_json()
        geo_j = folium.GeoJson(data=geo_j,
                               style_function=lambda x: {'fillColor': ñ["color"],"color":"black","weight": 1.3,"fillOpacity":1})
        folium.Popup(str(ñ["nombdist"])+": "+str(ñ["total"])).add_to(geo_j)
        geo_j.add_to(mapa0)

for x in range(a3.shape[0]):
    heatmap(x)
    
for x in range(a4.shape[0]):
    heatmap2(x)  

# delay=5
# fn='map.html'
# tmpurl='file://{path}/{mapfile}'.format(path=os.getcwd(),mapfile=fn)
# mapa0.save(fn)

# browser = webdriver.Chrome(ChromeDriverManager().install())
# browser.get(tmpurl)
# #Give the map tiles some time to load
# time.sleep(delay)
# browser.save_screenshot('MBUFFER MAPACALOR.png')
# browser.quit()

mapa0
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_31445540e79b69eedaa8c9fb66e65cd7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_31445540e79b69eedaa8c9fb66e65cd7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_31445540e79b69eedaa8c9fb66e65cd7 = L.map(
#                 &quot;map_31445540e79b69eedaa8c9fb66e65cd7&quot;,
#                 {
#                     center: [-12.05, -76.9],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_77b487036a7646b0cb70e69daa45de1e = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_31445540e79b69eedaa8c9fb66e65cd7);
#
#
#                 var lat_lng_popup_11b325336eb65a3d56167ffc67169b08 = L.popup();
#                 function latLngPop(e) {
#                     lat_lng_popup_11b325336eb65a3d56167ffc67169b08
#                         .setLatLng(e.latlng)
#                         .setContent(e.latlng.lat.toFixed(6) + &quot;, &quot; + e.latlng.lng.toFixed(6))
#                         .openOn(map_31445540e79b69eedaa8c9fb66e65cd7);
#                     }
#                 map_31445540e79b69eedaa8c9fb66e65cd7.on(&#x27;click&#x27;, latLngPop);
#
#
#         function geo_json_2843def026573e2402d4ddee1856f868_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#0077c1&quot;, &quot;fillOpacity&quot;: 1, &quot;weight&quot;: 1.3};
#             }
#         }
#
#         function geo_json_2843def026573e2402d4ddee1856f868_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_2843def026573e2402d4ddee1856f868 = L.geoJson(null, {
#                 onEachFeature: geo_json_2843def026573e2402d4ddee1856f868_onEachFeature,
#
#                 style: geo_json_2843def026573e2402d4ddee1856f868_styler,
#         });
#
#         function geo_json_2843def026573e2402d4ddee1856f868_add (data) {
#             geo_json_2843def026573e2402d4ddee1856f868
#                 .addData(data)
#                 .addTo(map_31445540e79b69eedaa8c9fb66e65cd7);
#         }
#             geo_json_2843def026573e2402d4ddee1856f868_add({&quot;bbox&quot;: [-77.06314536486667, -12.09304333658065, -77.0363167599105, -12.064467175319862], &quot;features&quot;: [{&quot;bbox&quot;: [-77.06314536486667, -12.09304333658065, -77.0363167599105, -12.064467175319862], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-77.03761846292167, -12.064467175319862], [-77.0363167599105, -12.07985338842309], [-77.041747481561, -12.080610928751298], [-77.04193494344287, -12.082902235849474], [-77.04628252341968, -12.08304031236048], [-77.05325720475616, -12.09304333658065], [-77.06314536486667, -12.086482428821], [-77.0456698611751, -12.065251980394521], [-77.03761846292167, -12.064467175319862]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         var popup_fe5e3bfd7a9d44abfccfa32293513138 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6a6e46483dcc39eb58abd86c37533e90 = $(`&lt;div id=&quot;html_6a6e46483dcc39eb58abd86c37533e90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JESUS MARIA: 2.5982437133789062&lt;/div&gt;`)[0];
#                 popup_fe5e3bfd7a9d44abfccfa32293513138.setContent(html_6a6e46483dcc39eb58abd86c37533e90);
#
#
#
#         geo_json_2843def026573e2402d4ddee1856f868.bindPopup(popup_fe5e3bfd7a9d44abfccfa32293513138)
#         ;
#
#
#
#
#         function geo_json_a9e19d0f1619cbfffd013902bfd88bb2_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#009dda&quot;, &quot;fillOpacity&quot;: 1, &quot;weight&quot;: 1.3};
#             }
#         }
#
#         function geo_json_a9e19d0f1619cbfffd013902bfd88bb2_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_a9e19d0f1619cbfffd013902bfd88bb2 = L.geoJson(null, {
#                 onEachFeature: geo_json_a9e19d0f1619cbfffd013902bfd88bb2_onEachFeature,
#
#                 style: geo_json_a9e19d0f1619cbfffd013902bfd88bb2_styler,
#         });
#
#         function geo_json_a9e19d0f1619cbfffd013902bfd88bb2_add (data) {
#             geo_json_a9e19d0f1619cbfffd013902bfd88bb2
#                 .addData(data)

# %%
finalplis1=finalplis0[["distrito","pobreza"]].groupby(["distrito"]).mean().reset_index()
finalplis1.loc[(finalplis1["distrito"].apply(lambda x: x in list(a["nombdist"]))==False)&(finalplis1["distrito"].apply(lambda x: "BRE" in str(x))),"distrito"]="BREÑA"
finalplis1.loc[(finalplis1["distrito"].apply(lambda x: x in list(a["nombdist"]))==False)&(finalplis1["distrito"].apply(lambda x: "MAG" in str(x))),"distrito"]="MAGDALENA DEL MAR"

finalplis=finalplis1.rename(columns={"distrito":"nombdist","pobreza":"total"})

a1=a.loc[(a["nombprov"]=="LIMA")|(a["nombdep"].apply(lambda x: "CALLAO" in x))]

a1_0=a1.merge(finalplis, how="left", on="nombdist")

a3=a1_0.loc[a1_0["total"].isna()==False].copy()

colores=list(reversed([
'#1c2475','#18297a','#122e7f','#083385','#00388a','#003d8f',
'#004293','#004798','#004b9d','#0050a1','#0055a6','#005aaa',
'#005fae','#0063b2','#0068b6','#006dba','#0072bd','#0077c1',
'#007cc4','#0080c8','#0085cb','#008ace','#008fd1','#0094d4',
'#0099d7','#009dda','#00a2dc','#00a7df','#00ace1','#00b1e4',
'#00b6e6','#00bae8','#00bfeb','#00c4ed','#00c9ef','#00cef1',
'#00d3f3','#00d7f4','#00dcf6','#1ae1f8']))

bins=np.linspace(min(a3["total"].apply(lambda x: float(x))),max(a3['total'].apply(lambda x: float(x))),len(colores)+1)
a3['color']=pd.cut(a3["total"],bins,labels=colores,include_lowest=True)


a4=a1_0.loc[a1_0["total"].isna()==True].copy()
a4["color"]="#DADADA"


mapa0 = folium.Map(location=[-12.05, -76.9], zoom_start=10, tiles="Cartodb Positron")
folium.LatLngPopup().add_to(mapa0)

def heatmap(x):
    for _, ñ in a3.iloc[x:x+1,:].iterrows():
        sim_geo = geopandas.GeoSeries(ñ['geometry']).simplify(tolerance=0.001)
        geo_j = sim_geo.to_json()
        geo_j = folium.GeoJson(data=geo_j,
                               style_function=lambda x: {'fillColor': ñ["color"],"color":"black","weight": 1.3,"fillOpacity":1})
        folium.Popup(str(ñ["nombdist"])+": "+str(ñ["total"])).add_to(geo_j)
        geo_j.add_to(mapa0)
        
def heatmap2(x):
    for _, ñ in a4.iloc[x:x+1,:].iterrows():
        sim_geo = geopandas.GeoSeries(ñ['geometry']).simplify(tolerance=0.001)
        geo_j = sim_geo.to_json()
        geo_j = folium.GeoJson(data=geo_j,
                               style_function=lambda x: {'fillColor': ñ["color"],"color":"black","weight": 1.3,"fillOpacity":1})
        folium.Popup(str(ñ["nombdist"])+": "+str(ñ["total"])).add_to(geo_j)
        geo_j.add_to(mapa0)

for x in range(a3.shape[0]):
    heatmap(x)
    
for x in range(a4.shape[0]):
    heatmap2(x)  

# delay=5
# fn='map.html'
# tmpurl='file://{path}/{mapfile}'.format(path=os.getcwd(),mapfile=fn)
# mapa0.save(fn)

# browser = webdriver.Chrome(ChromeDriverManager().install())
# browser.get(tmpurl)
# #Give the map tiles some time to load
# time.sleep(delay)
# browser.save_screenshot('MBUFFER MAPACALOR.png')
# browser.quit()

mapa0
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5525cb7a05268b937deab2acca30137f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5525cb7a05268b937deab2acca30137f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5525cb7a05268b937deab2acca30137f = L.map(
#                 &quot;map_5525cb7a05268b937deab2acca30137f&quot;,
#                 {
#                     center: [-12.05, -76.9],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d16af39104d4a7f200cf3ff4534c551c = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5525cb7a05268b937deab2acca30137f);
#
#
#                 var lat_lng_popup_c9eba9a30d7061ab81f413216fd2609c = L.popup();
#                 function latLngPop(e) {
#                     lat_lng_popup_c9eba9a30d7061ab81f413216fd2609c
#                         .setLatLng(e.latlng)
#                         .setContent(e.latlng.lat.toFixed(6) + &quot;, &quot; + e.latlng.lng.toFixed(6))
#                         .openOn(map_5525cb7a05268b937deab2acca30137f);
#                     }
#                 map_5525cb7a05268b937deab2acca30137f.on(&#x27;click&#x27;, latLngPop);
#
#
#         function geo_json_c92706f733be983aee0cff4cf868d435_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#1c2475&quot;, &quot;fillOpacity&quot;: 1, &quot;weight&quot;: 1.3};
#             }
#         }
#
#         function geo_json_c92706f733be983aee0cff4cf868d435_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_c92706f733be983aee0cff4cf868d435 = L.geoJson(null, {
#                 onEachFeature: geo_json_c92706f733be983aee0cff4cf868d435_onEachFeature,
#
#                 style: geo_json_c92706f733be983aee0cff4cf868d435_styler,
#         });
#
#         function geo_json_c92706f733be983aee0cff4cf868d435_add (data) {
#             geo_json_c92706f733be983aee0cff4cf868d435
#                 .addData(data)
#                 .addTo(map_5525cb7a05268b937deab2acca30137f);
#         }
#             geo_json_c92706f733be983aee0cff4cf868d435_add({&quot;bbox&quot;: [-77.06314536486667, -12.09304333658065, -77.0363167599105, -12.064467175319862], &quot;features&quot;: [{&quot;bbox&quot;: [-77.06314536486667, -12.09304333658065, -77.0363167599105, -12.064467175319862], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-77.03761846292167, -12.064467175319862], [-77.0363167599105, -12.07985338842309], [-77.041747481561, -12.080610928751298], [-77.04193494344287, -12.082902235849474], [-77.04628252341968, -12.08304031236048], [-77.05325720475616, -12.09304333658065], [-77.06314536486667, -12.086482428821], [-77.0456698611751, -12.065251980394521], [-77.03761846292167, -12.064467175319862]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         var popup_cf9fef7d1ebce5ee475d09f0feabfda6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b2734f17b2136cd0a8b5778dae0f23da = $(`&lt;div id=&quot;html_b2734f17b2136cd0a8b5778dae0f23da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JESUS MARIA: 1870.0&lt;/div&gt;`)[0];
#                 popup_cf9fef7d1ebce5ee475d09f0feabfda6.setContent(html_b2734f17b2136cd0a8b5778dae0f23da);
#
#
#
#         geo_json_c92706f733be983aee0cff4cf868d435.bindPopup(popup_cf9fef7d1ebce5ee475d09f0feabfda6)
#         ;
#
#
#
#
#         function geo_json_6407b97b31f638254c7aafe3c43382c5_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#1c2475&quot;, &quot;fillOpacity&quot;: 1, &quot;weight&quot;: 1.3};
#             }
#         }
#
#         function geo_json_6407b97b31f638254c7aafe3c43382c5_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_6407b97b31f638254c7aafe3c43382c5 = L.geoJson(null, {
#                 onEachFeature: geo_json_6407b97b31f638254c7aafe3c43382c5_onEachFeature,
#
#                 style: geo_json_6407b97b31f638254c7aafe3c43382c5_styler,
#         });
#
#         function geo_json_6407b97b31f638254c7aafe3c43382c5_add (data) {
#             geo_json_6407b97b31f638254c7aafe3c43382c5
#                 .addData(data)
#                 .addTo(map_

# %%
finalplis0=pd.read_stata("GASOLINA 90.dta")

finalplis1=finalplis0.loc[finalplis0["producto"].apply(lambda x: "0" in str(x))].groupby(["distrito"])[["cantidad"]].mean().reset_index()
finalplis1.loc[(finalplis1["distrito"].apply(lambda x: x in list(a["nombdist"]))==False)&(finalplis1["distrito"].apply(lambda x: "BRE" in str(x))),"distrito"]="BREÑA"
finalplis1.loc[(finalplis1["distrito"].apply(lambda x: x in list(a["nombdist"]))==False)&(finalplis1["distrito"].apply(lambda x: "MAG" in str(x))),"distrito"]="MAGDALENA DEL MAR"

finalplis=finalplis1.rename(columns={"distrito":"nombdist","cantidad":"total"})

a1=a.loc[(a["nombprov"]=="LIMA")|(a["nombdep"].apply(lambda x: "CALLAO" in x))]

a1_0=a1.merge(finalplis, how="left", on="nombdist")

a3=a1_0.loc[a1_0["total"].isna()==False].copy()

colores=list(reversed([
'#1c2475','#18297a','#122e7f','#083385','#00388a','#003d8f',
'#004293','#004798','#004b9d','#0050a1','#0055a6','#005aaa',
'#005fae','#0063b2','#0068b6','#006dba','#0072bd','#0077c1',
'#007cc4','#0080c8','#0085cb','#008ace','#008fd1','#0094d4',
'#0099d7','#009dda','#00a2dc','#00a7df','#00ace1','#00b1e4',
'#00b6e6','#00bae8','#00bfeb','#00c4ed','#00c9ef','#00cef1',
'#00d3f3','#00d7f4','#00dcf6','#1ae1f8']))

bins=np.linspace(min(a3["total"].apply(lambda x: float(x))),max(a3['total'].apply(lambda x: float(x))),len(colores)+1)
a3['color']=pd.cut(a3["total"],bins,labels=colores,include_lowest=True)


a4=a1_0.loc[a1_0["total"].isna()==True].copy()
a4["color"]="#DADADA"


mapa0 = folium.Map(location=[-12.05, -76.9], zoom_start=10, tiles="Cartodb Positron")
folium.LatLngPopup().add_to(mapa0)

def heatmap(x):
    for _, ñ in a3.iloc[x:x+1,:].iterrows():
        sim_geo = geopandas.GeoSeries(ñ['geometry']).simplify(tolerance=0.001)
        geo_j = sim_geo.to_json()
        geo_j = folium.GeoJson(data=geo_j,
                               style_function=lambda x: {'fillColor': ñ["color"],"color":"black","weight": 1.3,"fillOpacity":1})
        folium.Popup(str(ñ["nombdist"])+": "+str(ñ["total"])).add_to(geo_j)
        geo_j.add_to(mapa0)
        
def heatmap2(x):
    for _, ñ in a4.iloc[x:x+1,:].iterrows():
        sim_geo = geopandas.GeoSeries(ñ['geometry']).simplify(tolerance=0.001)
        geo_j = sim_geo.to_json()
        geo_j = folium.GeoJson(data=geo_j,
                               style_function=lambda x: {'fillColor': ñ["color"],"color":"black","weight": 1.3,"fillOpacity":1})
        folium.Popup(str(ñ["nombdist"])+": "+str(ñ["total"])).add_to(geo_j)
        geo_j.add_to(mapa0)

for x in range(a3.shape[0]):
    heatmap(x)
    
for x in range(a4.shape[0]):
    heatmap2(x)  

# delay=5
# fn='map.html'
# tmpurl='file://{path}/{mapfile}'.format(path=os.getcwd(),mapfile=fn)
# mapa0.save(fn)

# browser = webdriver.Chrome(ChromeDriverManager().install())
# browser.get(tmpurl)
# #Give the map tiles some time to load
# time.sleep(delay)
# browser.save_screenshot('MBUFFER CANTIDAD 95.png')
# browser.quit()

mapa0
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6c0669dc15be8a452fed95fae5fc9896 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6c0669dc15be8a452fed95fae5fc9896&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6c0669dc15be8a452fed95fae5fc9896 = L.map(
#                 &quot;map_6c0669dc15be8a452fed95fae5fc9896&quot;,
#                 {
#                     center: [-12.05, -76.9],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8b9549c821ed2e32b973f4c6c77a3d2e = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6c0669dc15be8a452fed95fae5fc9896);
#
#
#                 var lat_lng_popup_694c1f39374aef383a553131d76be5f0 = L.popup();
#                 function latLngPop(e) {
#                     lat_lng_popup_694c1f39374aef383a553131d76be5f0
#                         .setLatLng(e.latlng)
#                         .setContent(e.latlng.lat.toFixed(6) + &quot;, &quot; + e.latlng.lng.toFixed(6))
#                         .openOn(map_6c0669dc15be8a452fed95fae5fc9896);
#                     }
#                 map_6c0669dc15be8a452fed95fae5fc9896.on(&#x27;click&#x27;, latLngPop);
#
#
#         function geo_json_99a6c210890a015d182f53e0cadd5794_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#00d3f3&quot;, &quot;fillOpacity&quot;: 1, &quot;weight&quot;: 1.3};
#             }
#         }
#
#         function geo_json_99a6c210890a015d182f53e0cadd5794_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_99a6c210890a015d182f53e0cadd5794 = L.geoJson(null, {
#                 onEachFeature: geo_json_99a6c210890a015d182f53e0cadd5794_onEachFeature,
#
#                 style: geo_json_99a6c210890a015d182f53e0cadd5794_styler,
#         });
#
#         function geo_json_99a6c210890a015d182f53e0cadd5794_add (data) {
#             geo_json_99a6c210890a015d182f53e0cadd5794
#                 .addData(data)
#                 .addTo(map_6c0669dc15be8a452fed95fae5fc9896);
#         }
#             geo_json_99a6c210890a015d182f53e0cadd5794_add({&quot;bbox&quot;: [-77.06314536486667, -12.09304333658065, -77.0363167599105, -12.064467175319862], &quot;features&quot;: [{&quot;bbox&quot;: [-77.06314536486667, -12.09304333658065, -77.0363167599105, -12.064467175319862], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-77.03761846292167, -12.064467175319862], [-77.0363167599105, -12.07985338842309], [-77.041747481561, -12.080610928751298], [-77.04193494344287, -12.082902235849474], [-77.04628252341968, -12.08304031236048], [-77.05325720475616, -12.09304333658065], [-77.06314536486667, -12.086482428821], [-77.0456698611751, -12.065251980394521], [-77.03761846292167, -12.064467175319862]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         var popup_a44531b90ca3ad53bc879ccc4a72a3c2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a28ba49e87bda466ae9d6bac3995f906 = $(`&lt;div id=&quot;html_a28ba49e87bda466ae9d6bac3995f906&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JESUS MARIA: 2118.5588235294117&lt;/div&gt;`)[0];
#                 popup_a44531b90ca3ad53bc879ccc4a72a3c2.setContent(html_a28ba49e87bda466ae9d6bac3995f906);
#
#
#
#         geo_json_99a6c210890a015d182f53e0cadd5794.bindPopup(popup_a44531b90ca3ad53bc879ccc4a72a3c2)
#         ;
#
#
#
#
#         function geo_json_c887c3b557777c072c1ae08496d64e1b_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#00d7f4&quot;, &quot;fillOpacity&quot;: 1, &quot;weight&quot;: 1.3};
#             }
#         }
#
#         function geo_json_c887c3b557777c072c1ae08496d64e1b_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_c887c3b557777c072c1ae08496d64e1b = L.geoJson(null, {
#                 onEachFeature: geo_json_c887c3b557777c072c1ae08496d64e1b_onEachFeature,
#
#                 style: geo_json_c887c3b557777c072c1ae08496d64e1b_styler,
#         });
#
#         function geo_json_c887c3b557777c072c1ae08496d64e1b_add (data) {
#             geo_json_c887c3b557777c072c1ae08496d64e1b
#                 .addData(data)

# %%
finalplis0=pd.read_stata("GASOLINA 95.dta")

finalplis1=finalplis0.loc[finalplis0["producto"].apply(lambda x: "5" in str(x))].groupby(["distrito"])[["cantidad"]].mean().reset_index()
finalplis1.loc[(finalplis1["distrito"].apply(lambda x: x in list(a["nombdist"]))==False)&(finalplis1["distrito"].apply(lambda x: "BRE" in str(x))),"distrito"]="BREÑA"
finalplis1.loc[(finalplis1["distrito"].apply(lambda x: x in list(a["nombdist"]))==False)&(finalplis1["distrito"].apply(lambda x: "MAG" in str(x))),"distrito"]="MAGDALENA DEL MAR"

finalplis=finalplis1.rename(columns={"distrito":"nombdist","cantidad":"total"})

a1=a.loc[(a["nombprov"]=="LIMA")|(a["nombdep"].apply(lambda x: "CALLAO" in x))]

a1_0=a1.merge(finalplis, how="left", on="nombdist")

a3=a1_0.loc[a1_0["total"].isna()==False].copy()

colores=list(reversed([
'#1c2475','#18297a','#122e7f','#083385','#00388a','#003d8f',
'#004293','#004798','#004b9d','#0050a1','#0055a6','#005aaa',
'#005fae','#0063b2','#0068b6','#006dba','#0072bd','#0077c1',
'#007cc4','#0080c8','#0085cb','#008ace','#008fd1','#0094d4',
'#0099d7','#009dda','#00a2dc','#00a7df','#00ace1','#00b1e4',
'#00b6e6','#00bae8','#00bfeb','#00c4ed','#00c9ef','#00cef1',
'#00d3f3','#00d7f4','#00dcf6','#1ae1f8']))

bins=np.linspace(min(a3["total"].apply(lambda x: float(x))),max(a3['total'].apply(lambda x: float(x))),len(colores)+1)
a3['color']=pd.cut(a3["total"],bins,labels=colores,include_lowest=True)


a4=a1_0.loc[a1_0["total"].isna()==True].copy()
a4["color"]="#DADADA"


mapa0 = folium.Map(location=[-12.05, -76.9], zoom_start=10, tiles="Cartodb Positron")
folium.LatLngPopup().add_to(mapa0)

def heatmap(x):
    for _, ñ in a3.iloc[x:x+1,:].iterrows():
        sim_geo = geopandas.GeoSeries(ñ['geometry']).simplify(tolerance=0.001)
        geo_j = sim_geo.to_json()
        geo_j = folium.GeoJson(data=geo_j,
                               style_function=lambda x: {'fillColor': ñ["color"],"color":"black","weight": 1.3,"fillOpacity":1})
        folium.Popup(str(ñ["nombdist"])+": "+str(ñ["total"])).add_to(geo_j)
        geo_j.add_to(mapa0)
        
def heatmap2(x):
    for _, ñ in a4.iloc[x:x+1,:].iterrows():
        sim_geo = geopandas.GeoSeries(ñ['geometry']).simplify(tolerance=0.001)
        geo_j = sim_geo.to_json()
        geo_j = folium.GeoJson(data=geo_j,
                               style_function=lambda x: {'fillColor': ñ["color"],"color":"black","weight": 1.3,"fillOpacity":1})
        folium.Popup(str(ñ["nombdist"])+": "+str(ñ["total"])).add_to(geo_j)
        geo_j.add_to(mapa0)

for x in range(a3.shape[0]):
    heatmap(x)
    
for x in range(a4.shape[0]):
    heatmap2(x)  

# delay=5
# fn='map.html'
# tmpurl='file://{path}/{mapfile}'.format(path=os.getcwd(),mapfile=fn)
# mapa0.save(fn)

# browser = webdriver.Chrome(ChromeDriverManager().install())
# browser.get(tmpurl)
# #Give the map tiles some time to load
# time.sleep(delay)
# browser.save_screenshot('MBUFFER CANTIDAD 95.png')
# browser.quit()

mapa0
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_93d2c577c55d06614068cfbd9a231faa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_93d2c577c55d06614068cfbd9a231faa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_93d2c577c55d06614068cfbd9a231faa = L.map(
#                 &quot;map_93d2c577c55d06614068cfbd9a231faa&quot;,
#                 {
#                     center: [-12.05, -76.9],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1b1edbc3b26e8ef9bf8416bef949fd7e = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_93d2c577c55d06614068cfbd9a231faa);
#
#
#                 var lat_lng_popup_6e98a5ffb8010e0195571dbcaa6e9672 = L.popup();
#                 function latLngPop(e) {
#                     lat_lng_popup_6e98a5ffb8010e0195571dbcaa6e9672
#                         .setLatLng(e.latlng)
#                         .setContent(e.latlng.lat.toFixed(6) + &quot;, &quot; + e.latlng.lng.toFixed(6))
#                         .openOn(map_93d2c577c55d06614068cfbd9a231faa);
#                     }
#                 map_93d2c577c55d06614068cfbd9a231faa.on(&#x27;click&#x27;, latLngPop);
#
#
#         function geo_json_7e92d6217424ad429a4f369f61af473f_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#00bae8&quot;, &quot;fillOpacity&quot;: 1, &quot;weight&quot;: 1.3};
#             }
#         }
#
#         function geo_json_7e92d6217424ad429a4f369f61af473f_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_7e92d6217424ad429a4f369f61af473f = L.geoJson(null, {
#                 onEachFeature: geo_json_7e92d6217424ad429a4f369f61af473f_onEachFeature,
#
#                 style: geo_json_7e92d6217424ad429a4f369f61af473f_styler,
#         });
#
#         function geo_json_7e92d6217424ad429a4f369f61af473f_add (data) {
#             geo_json_7e92d6217424ad429a4f369f61af473f
#                 .addData(data)
#                 .addTo(map_93d2c577c55d06614068cfbd9a231faa);
#         }
#             geo_json_7e92d6217424ad429a4f369f61af473f_add({&quot;bbox&quot;: [-77.06314536486667, -12.09304333658065, -77.0363167599105, -12.064467175319862], &quot;features&quot;: [{&quot;bbox&quot;: [-77.06314536486667, -12.09304333658065, -77.0363167599105, -12.064467175319862], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-77.03761846292167, -12.064467175319862], [-77.0363167599105, -12.07985338842309], [-77.041747481561, -12.080610928751298], [-77.04193494344287, -12.082902235849474], [-77.04628252341968, -12.08304031236048], [-77.05325720475616, -12.09304333658065], [-77.06314536486667, -12.086482428821], [-77.0456698611751, -12.065251980394521], [-77.03761846292167, -12.064467175319862]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         var popup_67d2925f0ff575d826778398ab25d97a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bbc0bb5d6e16e175010c788de5bc202c = $(`&lt;div id=&quot;html_bbc0bb5d6e16e175010c788de5bc202c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JESUS MARIA: 4757.176470588235&lt;/div&gt;`)[0];
#                 popup_67d2925f0ff575d826778398ab25d97a.setContent(html_bbc0bb5d6e16e175010c788de5bc202c);
#
#
#
#         geo_json_7e92d6217424ad429a4f369f61af473f.bindPopup(popup_67d2925f0ff575d826778398ab25d97a)
#         ;
#
#
#
#
#         function geo_json_f1215d65db4307401d74b4623c31814f_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#00d7f4&quot;, &quot;fillOpacity&quot;: 1, &quot;weight&quot;: 1.3};
#             }
#         }
#
#         function geo_json_f1215d65db4307401d74b4623c31814f_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_f1215d65db4307401d74b4623c31814f = L.geoJson(null, {
#                 onEachFeature: geo_json_f1215d65db4307401d74b4623c31814f_onEachFeature,
#
#                 style: geo_json_f1215d65db4307401d74b4623c31814f_styler,
#         });
#
#         function geo_json_f1215d65db4307401d74b4623c31814f_add (data) {
#             geo_json_f1215d65db4307401d74b4623c31814f
#                 .addData(data)
